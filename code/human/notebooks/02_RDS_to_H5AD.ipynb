# %%
library(reticulate)
library(sceasy)
library(Seurat)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:base’:
#
#     intersect

# %%
getwd()
# Out:
# [1] "/ictstr01/home/aih/shrey.parikh/PDAC/PDAC/final_code"

# %%
seurat_object <- readRDS('/ictstr01/groups/ml01/workspace/shrey.parikh/PDAC/raw_data/Zenodo/Data/pk_all.rds')

# %%
seurat_object
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
# An object of class Seurat
# 38919 features across 136163 samples within 2 assays
# Active assay: RNA (34746 features, 0 variable features)
#  2 layers present: counts, data
#  1 other assay present: integrated
#  2 dimensional reductions calculated: pca, umap

# %%
# Access the counts matrix from the active assay
raw_counts <- GetAssayData(object = seurat_object, assay = "RNA", layer = "data")

# %%
raw_counts
# Out:
#   [[ suppressing 32 column names ‘T1_AAACCTGAGATGTCGG’, ‘T1_AAACGGGGTCATGCAT’, ‘T1_AAAGATGCATGTTGAC’ ... ]]
#
#   [[ suppressing 32 column names ‘T1_AAACCTGAGATGTCGG’, ‘T1_AAACGGGGTCATGCAT’, ‘T1_AAAGATGCATGTTGAC’ ... ]]
#
#   [[ suppressing 32 column names ‘T1_AAACCTGAGATGTCGG’, ‘T1_AAACGGGGTCATGCAT’, ‘T1_AAAGATGCATGTTGAC’ ... ]]
# 34746 x 136163 sparse Matrix of class "dgCMatrix"
#
# LINC00115    .        .        .        .        .        .        .        .
# FAM41C       .        .        .        .        .        .        .        .
# SAMD11       .        .        .        .        .        .        .        .
# NOC2L        1.056468 .        .        .        .        .        .        .
# KLHL17       .        .        .        .        .        .        .        .
# PLEKHN1      .        .        .        .        .        .        .        .
# HES4         1.582410 2.287518 .        .        1.172760 .        .        .
# ...

# %%
# 1. Check if all counts are integers
are_integers <- all(raw_counts == as.integer(raw_counts))
print(paste("Are raw counts integers?", are_integers))

# # 2. Calculate basic statistics
# # Mean raw counts
# mean_raw_counts <- mean(raw_counts)
# print(paste("Mean raw counts:", mean_raw_counts))

# Range of raw counts
range_raw_counts <- range(raw_counts)
print(paste("Range of raw counts:", range_raw_counts[1], "to", range_raw_counts[2]))

# # Percentage of zero counts
# percentage_zeros <- mean(raw_counts == 0) * 100
# print(paste("Percentage of zero counts:", round(percentage_zeros, 2), "%"))

# Optional: Create a separator for clarity
cat(rep("-", 50), "\n")
# Out:
# Warning message:
# “The following arguments are not used: layers”
# Warning message in .M2v(x):
# “sparse->dense coercion: allocating vector of size 35.2 GiB”
# Warning message in .sparse2dense(e1):
# “sparse->dense coercion: allocating vector of size 35.2 GiB”
# Warning message in .sparse2dense(e2):
# “sparse->dense coercion: allocating vector of size 35.2 GiB”

# %%
sceasy::convertFormat(seurat_object, from="seurat", to="anndata",
                       outFile='pk_all.h5ad')
# Out:
# AnnData object with n_obs × n_vars = 136163 × 34746
#     obs: 'CELL', 'Patient', 'Type', 'Cell_type', 'celltype0', 'celltype1', 'celltype2', 'celltype3', 'Patient2', 'nCount_RNA', 'nFeature_RNA', 'Project', 'orig.ident', 'Stage', 'Grade', 'Gender', 'Age', 'Percent_mito', 'Percent_ribo', 'Percent_hemo', 'percent.mt', 'predicted.id', 'prediction.score.Fibroblast.cell', 'prediction.score.Stellate.cell', 'prediction.score.Macrophage.cell', 'prediction.score.Endothelial.cell', 'prediction.score.T.cell', 'prediction.score.B.cell', 'prediction.score.Ductal.cell.type.2', 'prediction.score.Endocrine.cell', 'prediction.score.Ductal.cell.type.1', 'prediction.score.Acinar.cell', 'prediction.score.max', 'classical_score1', 'basal_score1', 'classical_score21', 'basal_score21', 'endocrine_score_1', 'immune_score_1', 'exocrine_score_1', 'activated_stroma_score_1', 'histone_score_1', 'normal_stroma_score_1', 'olfactory_score_1', 'na_score_1'
#     var: 'name'
#     obsm: 'X_pca', 'X_umap'

# %%
#check publications for number of genes and methods
#summary of the metadata 
#check karins mouse pancreas paper
