# %%
import os
import scanpy as sc
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import warnings
import anndata as ad

# %%
class Concat:
    def __init__(self, base_path, output_file, dataset_name):
        self.base_path = base_path
        self.output_file = output_file
        self.dataset_name = dataset_name
        self.ann_data_list = []
        self.process_directories()
        
    def process_directories(self):
        highly_variable_genes = None 
        for root, dirs, files in os.walk(self.base_path):
            for file in files:
                if file.endswith("_output_preprocessed.h5ad"):
                    file_path = os.path.join(root, file)
                    print(f"Loading Anndata: {file_path}")
                    adata = self.load_anndata(file_path)
                    print("Adding Metadata")
                    self.add_metadata(adata, root)
                    # print('Calculating HVGs')
                    # self.calculate_HVGs(adata)
                    self.ann_data_list.append(adata)
        print(self.ann_data_list)            
        print('Concatinating Datasets')
        self.concat_and_save()

    def load_anndata(self, file_path):
        return sc.read_h5ad(file_path)

    def add_metadata(self, adata, directory_name):
        print('Changing Var Index')
        adata.var['1'] = adata.var['1'].astype(str)
        adata.var.index = adata.var['1']
        adata.var_names_make_unique()
        # Extracting directory name from the path
        directory_name = os.path.basename(directory_name)
        # Adding columns to adata.obs
        adata.obs['ID'] = directory_name
        adata.obs['Dataset'] = self.dataset_name

    # def calculate_HVGs(self, adata):
    #     sc.pp.normalize_total(adata, target_sum=1e4)
    #     sc.pp.log1p(adata)
    #     sc.pp.highly_variable_genes(adata, n_top_genes=3000)
    #     adata._inplace_subset_var(adata.var['highly_variable'])
    
    def concat_and_save(self):
        if self.ann_data_list:
            concatenated_anndata = ad.concat(self.ann_data_list, join='outer', fill_value=0)
            concatenated_anndata.write_h5ad(self.output_file)

# %%
Simeone = Concat(base_path='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone', 
                 output_file='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/Simeone_concat.h5ad', dataset_name='Simeone')
# Out:
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204125_P17/GSM6204125_P17_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204130_P22/GSM6204130_P22_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204112_P04/GSM6204112_P04_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204111_P03/GSM6204111_P03_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204123_P15/GSM6204123_P15_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204116_P08/GSM6204116_P08_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204134_P26/GSM6204134_P26_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204131_P23/GSM6204131_P23_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204114_P06/GSM6204114_P06_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204119_P11/GSM6204119_P11_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204133_P25/GSM6204133_P25_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204124_P16/GSM6204124_P16_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204120_P12/GSM6204120_P12_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204132_P24/GSM6204132_P24_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204115_P07/GSM6204115_P07_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204110_P02/GSM6204110_P02_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204127_P19/GSM6204127_P19_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204126_P18/GSM6204126_P18_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204135_P27/GSM6204135_P27_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204129_P21/GSM6204129_P21_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204117_P09/GSM6204117_P09_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204118_P10/GSM6204118_P10_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204121_P13/GSM6204121_P13_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204113_P05/GSM6204113_P05_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204109_P01/GSM6204109_P01_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204128_P20/GSM6204128_P20_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/GSM6204122_P14/GSM6204122_P14_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# [AnnData object with n_obs × n_vars = 4796 × 18527
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 5509 × 18665
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2675 × 18827
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 25049 × 20719
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 7705 × 21030
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 7904 × 18107
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 13415 × 17180
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 8548 × 20605
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3223 × 15904
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 6878 × 19648
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 9712 × 18652
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3180 × 16780
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3457 × 18947
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3003 × 16114
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 4355 × 19218
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3629 × 18467
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 14823 × 20267
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 18596 × 21835
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 9876 × 20564
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2255 × 17937
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1484 × 16020
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 4807 × 18714
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2346 × 16966
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 13932 × 20717
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 5323 × 19131
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 10732 × 18275
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 16499 × 21199
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells']
# Concatinating Datasets
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
Lee = Concat(base_path='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee', 
             output_file='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/Lee_concat.h5ad', dataset_name='Lee')
# Out:
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-P4_filtered_feature_bc_matrix/PBMC-P4_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-VM_filtered_feature_bc_matrix/PBMC-VM_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/LiM_filtered_feature_bc_matrix/LiM_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/P1_filtered_feature_bc_matrix/P1_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-P3_filtered_feature_bc_matrix/PBMC-P3_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-LuM_filtered_feature_bc_matrix/PBMC-LuM_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/VM_filtered_feature_bc_matrix/VM_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-P1_filtered_feature_bc_matrix/PBMC-P1_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/P3_filtered_feature_bc_matrix/P3_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-LiM_filtered_feature_bc_matrix/PBMC-LiM_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/LuM_filtered_feature_bc_matrix/LuM_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-P2_filtered_feature_bc_matrix/PBMC-P2_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/PBMC-PM_filtered_feature_bc_matrix/PBMC-PM_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/P4_filtered_feature_bc_matrix/P4_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/P5_filtered_feature_bc_matrix/P5_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/P2_filtered_feature_bc_matrix/P2_filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# [AnnData object with n_obs × n_vars = 2666 × 11058
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3161 × 13349
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', 'n_cells', AnnData object with n_obs × n_vars = 10013 × 18243
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1379 × 10692
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3003 × 11342
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2171 × 12396
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1527 × 15242
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2863 × 12378
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3843 × 15559
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2133 × 12469
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2899 × 16359
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2820 × 11415
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3294 × 13140
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2072 × 14830
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 635 × 9555
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 968 × 11592
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells']
# Concatinating Datasets
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/Lee_concat.h5ad')
# Out:
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
Steele = Concat(base_path='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele', 
             output_file='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/Steele_concat.h5ad', dataset_name='Steele')
# Out:
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_2/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_4/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_4/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_10/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/Healthy_PBMC_1/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_5/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_7/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_7/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_16/filtered_gene_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_10B/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_2/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/AdjNorm_TISSUE_2/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_3/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_11B/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_1/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_15/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_12/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_11/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_5/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_10A/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_12/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_9/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/Healthy_PBMC_3/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/Healthy_PBMC_2/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_14/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_6/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_9/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_11A/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_16/filtered_gene_bc_matrices_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_13/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_3/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_1/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/Healthy_PBMC_4/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_TISSUE_8/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/AdjNorm_TISSUE_1/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_6/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_13/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_8/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/AdjNorm_TISSUE_3/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/PDAC_PBMC_15/filtered_feature_bc_matrix_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# [AnnData object with n_obs × n_vars = 1560 × 15152
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 4723 × 13639
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1631 × 15955
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1091 × 13093
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3128 × 13631
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1160 × 15762
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 4000 × 14756
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 6642 × 18255
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3814 × 12703
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', 'n_cells', AnnData object with n_obs × n_vars = 607 × 10811
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2777 × 13588
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2242 × 14616
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1929 × 16266
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1527 × 14946
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1934 × 13168
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2478 × 17724
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1089 × 13514
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1538 × 12928
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3982 × 13743
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 4516 × 12781
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2478 × 13744
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3336 × 13400
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 5665 × 15330
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2202 × 13320
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3522 × 13837
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1931 × 16289
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3676 × 13649
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2291 × 12549
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 839 × 14290
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', 'n_cells', AnnData object with n_obs × n_vars = 4414 × 17073
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2815 × 13595
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1050 × 15514
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2010 × 12408
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3910 × 17618
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3538 × 16468
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2571 × 13432
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 939 × 12028
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 4807 × 13283
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 751 × 13382
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3205 × 12679
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells']
# Concatinating Datasets
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/Steele_concat.h5ad')
# Out:
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zenodo/Data/pk_all_preprocessed.h5ad')

# %%
lee = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Lee/Lee_concat.h5ad')
# Out:
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
simeone = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Simeone/Simeone_concat.h5ad')
# Out:
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
steele = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Steele/Steele_concat.h5ad')
# Out:
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
Caronni = Concat(base_path='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni', 
             output_file='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/Caronni_concat.h5ad', dataset_name='Caronni')
# Out:
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727542_LPDAC/GSM6727542_LPDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727551_PDAC/GSM6727551_PDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727548_PDAC/GSM6727548_PDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727547_PDAC/GSM6727547_PDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727545_LPDAC/GSM6727545_LPDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727549_PDAC/GSM6727549_PDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727550_PDAC/GSM6727550_PDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727544_LPDAC/GSM6727544_LPDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727543_LPDAC/GSM6727543_LPDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/GSM6727546_PDAC/GSM6727546_PDAC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# [AnnData object with n_obs × n_vars = 12066 × 16566
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 3490 × 17222
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 8294 × 18005
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 7077 × 16402
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 5872 × 15846
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 7967 × 18877
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 13143 × 18355
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 4976 × 17336
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 2476 × 17765
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 9919 × 17099
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells']
# Concatinating Datasets
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
Zhang = Concat(base_path='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang', 
             output_file='/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/Zhang_concat.h5ad', dataset_name='Zhang')
# Out:
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910788_Case2-ZY_LM/GSM5910788_Case2-ZY_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910785_Case1-ZY_LM/GSM5910785_Case1-ZY_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910790_Case3-ZY_LM/GSM5910790_Case3-ZY_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910789_Case3-YF_PDAC/GSM5910789_Case3-YF_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910786_Case2-ZC_NPT/GSM5910786_Case2-ZC_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910791_Case4-ZY_LM/GSM5910791_Case4-ZY_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910787_Case2-YF_PDAC/GSM5910787_Case2-YF_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# Loading Anndata: /dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/GSM5910784_Case1-YF_PDAC/GSM5910784_Case1-YF_output_preprocessed.h5ad
# Adding Metadata
# Changing Var Index
# [AnnData object with n_obs × n_vars = 7778 × 17749
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 12030 × 18649
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 7663 × 19569
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 8239 × 19203
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 5924 × 15265
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 1206 × 12526
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 10556 × 18172
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells', AnnData object with n_obs × n_vars = 19139 × 18914
#     obs: 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'ID', 'Dataset'
#     var: '0', '1', '2', 'n_cells']
# Concatinating Datasets
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
zhang = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Zhang/Zhang_concat.h5ad')
# Out:
# /dss/dsshome1/05/di35nod/miniconda3/envs/preprocess/lib/python3.11/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
caronni = sc.read_h5ad('/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di35nod/PDAC_data/raw_data/Caronni/Caronni_concat.h5ad')

# %%
#TODO: Is it necessary to read the object after concatenation all the time? if not remove
