# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.legend import Legend 
from matplotlib import font_manager
from matplotlib import gridspec
import seaborn as sns
import anndata as ad
import scanpy as sc
import yaml
from pathlib import Path
import warnings
from collections import Counter
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, leaves_list
import nbformat
from collections import defaultdict
import plotly.graph_objects as go

warnings.filterwarnings('ignore')

from scripts.atlas_plots import AtlasPlotting

# %%
#adata = sc.read_h5ad("/mnt/storage/Daniele/atlases/human/Human_Atlas_Harmonised.h5ad")
adata = ad.read_zarr("/mnt/ssd/atlases/Human_Atlas_Harmonised.zarr")
adata_core = ad.read_zarr("/mnt/ssd/atlases/Human_Atlas_Harmonised_Core.zarr")

# %%
figgen = AtlasPlotting("config/config.yml",output_dir="/mnt/t06/Cell/AG-Saur/KKF2/Daniele/pdac_atlas_figures/")

# %%
fig_counts, fig_rel = figgen.compare_cell_abundance_barplot(
    adata,
    adata_core,
    label2='Core',
    label1='Core + Extension',
    cell_type_column='Level_2',
    figsize=(20,10),
    save_name='core_vs_extension_cell_type_abundance_level2'
)
fig_counts, fig_rel = figgen.compare_cell_abundance_barplot(
    adata,
    adata_core, 
    label2='Core',
    label1='Core + Extension',
    cell_type_column='Level_3',
    figsize=(20,10),
    save_name='core_vs_extension_cell_type_abundance_level3'
)
fig_counts, fig_rel = figgen.compare_cell_abundance_barplot(
    adata,
    adata_core, 
    label2='Core',
    label1='Core + Extension',
    cell_type_column='Level_4',
    figsize=(20,10),
    save_name='core_vs_extension_cell_type_abundance_level4'
)
